# %% [markdown]
# #Machine Learning Project Lifecycle
#
# Understanding the Problem Statement.
#
# Collection of Data.
#
# EDA.
#
# Data Cleaning
#
# Data Pre-processing
#
# Model Training
#
# Evaluation of model.

# %% [markdown]
# #The problem Statement
#
# The Influence of Gender, Race, and Parent Level of Education to Student Performance in Exams

# %% [markdown]
# Importing the requisite libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sb

# %% [markdown]
# Data Ingestion

# %%
df = pd.read_csv("stud.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# The dataset has 1000 observations/rows and 8 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# There are no null values in the dataset

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Statistical and Graphical Analysis

# %%
df["gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df[df["gender"] == "female"].count()
# Out:
# gender                         518
# race/ethnicity                 518
# parental level of education    518
# lunch                          518
# test preparation course        518
# math score                     518
# reading score                  518
# writing score                  518
# dtype: int64

# %% [markdown]
# The record consists of 518 females and 482 males .Thus the dataset is balanced.

# %%
px.bar(x = df["gender"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["race/ethnicity"].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %% [markdown]
# The record consists of students from 5 different races/ethnicities.

# %%
px.bar(x = df["race/ethnicity"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The ethnicity wise count in descending order is as follows.
#
# group C
#
# group D
#
# group B
#
# group E
#
# group A
#
# Number of students from Group A are less than 1/10th of the total observations in the dataset.

# %%
df["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
px.histogram(x = df["parental level of education"], color = df["race/ethnicity"],barmode = "group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1) Very few (around 50-55) parents are having master's degree. Amongst them majority belong to the ethnicity "group D" and "group C".
#
# 2) Majority of the parents have "some college" or "associate degree".

# %%
px.histogram(x = df["parental level of education"],color = df["gender"],barmode = "group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Overall female's parents are highly educated

# %% [markdown]
# LUNCH

# %%
px.bar(x = df["lunch"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# "Standard" Lunch was opted for more than 600 students.

# %%
px.histogram(x = df["lunch"], color = df["race/ethnicity"],barmode = "group" )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(x = df["lunch"], color = df["parental level of education"],barmode = "group" )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Overall majority of students opted for standard lunch.

# %%
px.bar( x = df["test preparation course"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# More than 600 students did not opt for test preparation course

# %%
px.histogram(x = df["test preparation course"] , color = df["race/ethnicity"] ,barmode = "group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(x = df["test preparation course"] , color = df["parental level of education"] ,barmode = "group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Roughly 60%-70% students irrespective of their race/ethnicity did not take the test preparation course. Except that for group E where the proportion of test takers was approx 42%.

# %%
df["Average_Score"] = (df["math score"] + df["reading score"] + df["writing score"])/3

# %%
print(df[df["test preparation course"] == "none"]["Average_Score"].mean())
print(df[df["test preparation course"] == "completed"]["Average_Score"].mean())
# Out:
# 65.03894080996885
# 72.66945996275605

# %% [markdown]
# The Test Preparation Course does affect the marks.
#
# The Average score of students who took the course is greater when compared to non test takers.

# %%
print(df[df["lunch"] == "standard"]["Average_Score"].mean())
print(df[df["lunch"] == "free/reduced"]["Average_Score"].mean())
# Out:
# 70.83720930232558
# 62.199061032863845

# %% [markdown]
# The Average score of students who took standard lunch is greater.

# %%
print(df[df["race/ethnicity"] == "group A"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group B"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group C"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group D"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group E"]["Average_Score"].mean())
# Out:
# 62.992509363295895
# 65.46842105263158
# 67.13166144200628
# 69.1793893129771
# 72.75238095238095

# %% [markdown]
# The students from group E performed the best. 40% of the Group E students had opted for test and

# %%
print(df[df["race/ethnicity"] == "group A"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group B"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group C"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group D"]["Average_Score"].mean())
print(df[df["race/ethnicity"] == "group E"]["Average_Score"].mean())
# Out:
# 62.992509363295895
# 65.46842105263158
# 67.13166144200628
# 69.1793893129771
# 72.75238095238095

# %%
print(df[df["parental level of education"] == "high school"]["Average_Score"].mean())
print(df[df["parental level of education"] == "some high school"]["Average_Score"].mean())
print(df[df["parental level of education"] == "some college"]["Average_Score"].mean())
print(df[df["parental level of education"] == "associate's degree"]["Average_Score"].mean())
print(df[df["parental level of education"] == "bachelor's degree"]["Average_Score"].mean())
print(df[df["parental level of education"] == "master's degree"]["Average_Score"].mean())
# Out:
# 63.0969387755102
# 65.10800744878958
# 68.47640117994099
# 69.56906906906907
# 71.92372881355934
# 73.59887005649718

# %% [markdown]
# Yes parental level of education does affect the score.

# %%
print(df[df["gender"] == "male"]["Average_Score"].mean())
print(df[df["gender"] == "female"]["Average_Score"].mean())
# Out:
# 65.8374827109267
# 69.56949806949807

# %% [markdown]
# #Final Observations
#
# 1) The data has very less representation of students from group A.
#
# 2) Majority of Parents have "some college"/"associate degree".
#
# 3) Students opting for standard lunch got higher marks.
#
# 4) Students opting for test preparation course got higher marks.
#
# 5) Parental Level of Education does affect the score.
#
# 6) Females performed better than males.
